# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#is there any null values in dataset?

df.isnull().sum()

#no
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.heatmap(df.isnull())

#obs:single shade---> null val not present
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df,hue='species')

#in summary
#obs:specie versicolor and virginica seem to have similar values for petal length, while Iris setosa belongs in a category all by itself.

# %%
#which species have max and min sepal length?
max_sepal_length=df[df['sepal_length']==df['sepal_length'].max()][['species','sepal_length']]
max_sepal_length
# Out:
#        species  sepal_length
# 131  virginica           7.9

# %%
min_sepal_length=df[df['sepal_length']==df['sepal_length'].min()][['species','sepal_length']]
min_sepal_length
# Out:
#    species  sepal_length
# 13  setosa           4.3

# %%
sns.jointplot(x='species', y='sepal_length',data=df)


#obs: virginica have max sepal lenghth i.e 7.9 and setosa have min length i.e 4.3

# %%
#which species have max and min sepal width?

max_sepal_width=df[df['sepal_width']==df['sepal_width'].max()][['species','sepal_width']]
max_sepal_width
# Out:
#    species  sepal_width
# 15  setosa          4.4

# %%
min_sepal_width=df[df['sepal_width']==df['sepal_width'].min()][['species','sepal_width']]
min_sepal_width
# Out:
#        species  sepal_width
# 60  versicolor          2.0

# %%
sns.barplot(x='species',y='sepal_width',data=df)

#obs: setosa species have the max sepal width i.e 4.4 and versicolor have the min sepal width i.e 2.0
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
#which species have max and min petal_length?

max_petal_length=df[df['petal_length']==df['petal_length'].max()][['species','petal_length']]
max_petal_length
# Out:
#        species  petal_length
# 118  virginica           6.9

# %%
min_petal_length=df[df['petal_length']==df['petal_length'].min()][['species','petal_length']]
min_petal_length
# Out:
#    species  petal_length
# 22  setosa           1.0

# %%
sns.barplot(x='species',y='petal_length',data=df)

#obs:virginica species have the max petal length i.e 6.9 and setosa have the min petal length i.e 1.0
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#which species have max and min petal_width?

max_petal_width=df[df['petal_width']==df['petal_width'].max()][['species','petal_width']].head(1)
max_petal_width
# Out:
#        species  petal_width
# 100  virginica          2.5

# %%
min_petal_width=df[df['petal_width']==df['petal_width'].min()][['species','petal_width']].head(1)
min_petal_width
# Out:
#   species  petal_width
# 9  setosa          0.1

# %%
sns.barplot(x='species',y='petal_width',data=df)

# virginica have max petal width i.e 2.5 and setosa have min petal width i.e 0.1
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
# what are the most common feature of verginica species

len_sepal=df['sepal_length'].mode()
print("sepal_length",len_sepal)
width_sepal=df['sepal_width'].mode()
print('sepal_width',width_sepal)
length_petal=df['petal_length'].mode().head(1)
print('petal_length',length_petal)
width_petal=df['petal_width'].mode().head(1)
print('petal1_width',width_petal)
# Out:
# sepal_length 0    5.0
# Name: sepal_length, dtype: float64
# sepal_width 0    3.0
# Name: sepal_width, dtype: float64
# petal_length 0    1.4
# Name: petal_length, dtype: float64
# petal1_width 0    0.2
# Name: petal_width, dtype: float64

# %%
#what is average sepal_length of all species

df['sepal_length'].mean()

#obs:5.843333333333335
# Out:
# 5.843333333333335

# %%
#what is average sepal_width of all species

df['sepal_width'].mean()

#obs:3.057333333333334
# Out:
# 3.057333333333334

# %%
#what is average petal_width of all species

df['petal_width'].mean()

#obs:1.199333333333334
# Out:
# 1.199333333333334

# %%
#what is average petal_length of all species

df['petal_length'].mean()

#obs:3.7580000000000027
# Out:
# 3.7580000000000027

# %%
# total count of data available for all species i.e setosa ,virginica and versicolor ?

setosa=df[df['species']=='setosa'].value_counts().sum()
setosa
# Out:
# 50

# %%
virginica=df[df['species']=='virginica'].value_counts().sum()
virginica
# Out:
# 50

# %%
versicolor=df[df['species']=='versicolor'].value_counts().sum()
versicolor
# Out:
# 50

# %%
sns.countplot(x='species',data=df)

#obs: we have 50,50,50 data available for all the species as total count is same for all species
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.boxplot(x='sepal_length',y='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
#finding relation between sepal_length and petal_length

sns.scatterplot(x=df['sepal_length'], y=df['petal_length'],hue=df['species'])

#obs: versicolor and virginica are much closely related
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#finding relation between sepal_length and petal_length

sns.lmplot(x="sepal_length", y="petal_length", hue="species", data=df)

# obs: positive slope in all cases hence species of iris having greater sepal length tends to have greater petal length as well
